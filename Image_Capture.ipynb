# %%
import cv2
import os

# Parameters
output_folder = "captured_faces"  # Folder to save images
num_images = 200  # Number of images to capture
image_prefix = "face"  # Prefix for image filenames
image_size = (200, 200)  # Resize captured faces to this size

# Create the output folder if it doesn't exist
if not os.path.exists(output_folder):
    os.makedirs(output_folder)

# Load Haar Cascade for face detection
cascade_path = "haarcascade_frontalface_default.xml"
face_cascade = cv2.CascadeClassifier(cascade_path)

if face_cascade.empty():
    raise IOError("Haar cascade XML file not loaded correctly.")

# Open the laptop camera
cap = cv2.VideoCapture(0)  # Use 0 for the default camera
if not cap.isOpened():
    raise IOError("Cannot access the camera.")

print("Press 'q' to quit early.")

# Start capturing images
count = 0
while count < num_images:
    ret, frame = cap.read()
    if not ret:
        print("Failed to grab frame. Exiting...")
        break

    # Detect faces in the frame (convert to grayscale for detection)
    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
    faces = face_cascade.detectMultiScale(gray, scaleFactor=1.1, minNeighbors=5)

    for (x, y, w, h) in faces:
        # Crop and resize the face in color
        face_color = frame[y:y+h, x:x+w]
        face_resized = cv2.resize(face_color, image_size)

        # Save the face image
        file_name = os.path.join(output_folder, f"{image_prefix}_{count+1}.jpg")
        cv2.imwrite(file_name, face_resized)
        print(f"Captured and saved: {file_name}")

        count += 1
        if count >= num_images:
            break

    # Display the frame
    cv2.imshow("Capturing Faces", frame)

    # Quit on 'q'
    if cv2.waitKey(1) & 0xFF == ord('q'):
        print("Exiting early...")
        break

# Release resources
cap.release()
cv2.destroyAllWindows()

print(f"Captured {count} face images in color. Images are saved in '{output_folder}'.")
# Out:
# Press 'q' to quit early.
# Captured and saved: captured_faces/face_1.jpg
# Captured and saved: captured_faces/face_2.jpg
# Captured and saved: captured_faces/face_3.jpg
# Captured and saved: captured_faces/face_4.jpg
# Captured and saved: captured_faces/face_5.jpg
# Captured and saved: captured_faces/face_6.jpg
# Captured and saved: captured_faces/face_7.jpg
# Captured and saved: captured_faces/face_8.jpg
# Captured and saved: captured_faces/face_9.jpg
# Captured and saved: captured_faces/face_10.jpg
# Captured and saved: captured_faces/face_11.jpg
# Captured and saved: captured_faces/face_12.jpg
# Captured and saved: captured_faces/face_13.jpg
# Captured and saved: captured_faces/face_14.jpg
# Captured and saved: captured_faces/face_15.jpg
# Captured and saved: captured_faces/face_16.jpg
# Captured and saved: captured_faces/face_17.jpg
# Captured and saved: captured_faces/face_18.jpg
# Captured and saved: captured_faces/face_19.jpg
# Captured and saved: captured_faces/face_20.jpg
# Captured and saved: captured_faces/face_21.jpg
# Captured and saved: captured_faces/face_22.jpg
# Captured and saved: captured_faces/face_23.jpg
# Captured and saved: captured_faces/face_24.jpg
# Captured and saved: captured_faces/face_25.jpg
# Captured and saved: captured_faces/face_26.jpg
# Captured and saved: captured_faces/face_27.jpg
# Captured and saved: captured_faces/face_28.jpg
# Captured and saved: captured_faces/face_29.jpg
# Captured and saved: captured_faces/face_30.jpg
# Captured and saved: captured_faces/face_31.jpg
# Captured and saved: captured_faces/face_32.jpg
# Captured and saved: captured_faces/face_33.jpg
# Captured and saved: captured_faces/face_34.jpg
# Captured and saved: captured_faces/face_35.jpg
# Captured and saved: captured_faces/face_36.jpg
# Captured and saved: captured_faces/face_37.jpg
# Captured and saved: captured_faces/face_38.jpg
# Captured and saved: captured_faces/face_39.jpg
# Captured and saved: captured_faces/face_40.jpg
# Captured and saved: captured_faces/face_41.jpg
# Captured and saved: captured_faces/face_42.jpg
# Captured and saved: captured_faces/face_43.jpg
# Captured and saved: captured_faces/face_44.jpg
# Captured and saved: captured_faces/face_45.jpg
# Captured and saved: captured_faces/face_46.jpg
# Captured and saved: captured_faces/face_47.jpg
# Captured and saved: captured_faces/face_48.jpg
# Captured and saved: captured_faces/face_49.jpg
# Captured and saved: captured_faces/face_50.jpg
# Captured and saved: captured_faces/face_51.jpg
# Captured and saved: captured_faces/face_52.jpg
# Captured and saved: captured_faces/face_53.jpg
# Captured and saved: captured_faces/face_54.jpg
# Captured and saved: captured_faces/face_55.jpg
# Captured and saved: captured_faces/face_56.jpg
# Captured and saved: captured_faces/face_57.jpg
# Captured and saved: captured_faces/face_58.jpg
# Captured and saved: captured_faces/face_59.jpg
# Captured and saved: captured_faces/face_60.jpg
# Captured and saved: captured_faces/face_61.jpg
# Captured and saved: captured_faces/face_62.jpg
# Captured and saved: captured_faces/face_63.jpg
# Captured and saved: captured_faces/face_64.jpg
# Captured and saved: captured_faces/face_65.jpg
# Captured and saved: captured_faces/face_66.jpg
# Captured and saved: captured_faces/face_67.jpg
# Captured and saved: captured_faces/face_68.jpg
# Captured and saved: captured_faces/face_69.jpg
# Captured and saved: captured_faces/face_70.jpg
# Captured and saved: captured_faces/face_71.jpg
# Captured and saved: captured_faces/face_72.jpg
# Captured and saved: captured_faces/face_73.jpg
# Captured and saved: captured_faces/face_74.jpg
# Captured and saved: captured_faces/face_75.jpg
# Captured and saved: captured_faces/face_76.jpg
# Captured and saved: captured_faces/face_77.jpg
# Captured and saved: captured_faces/face_78.jpg
# Captured and saved: captured_faces/face_79.jpg
# Captured and saved: captured_faces/face_80.jpg
# Captured and saved: captured_faces/face_81.jpg
# Captured and saved: captured_faces/face_82.jpg
# Captured and saved: captured_faces/face_83.jpg
# Captured and saved: captured_faces/face_84.jpg
# Captured and saved: captured_faces/face_85.jpg
# Captured and saved: captured_faces/face_86.jpg
# Captured and saved: captured_faces/face_87.jpg
# Captured and saved: captured_faces/face_88.jpg
# Captured and saved: captured_faces/face_89.jpg
# Captured and saved: captured_faces/face_90.jpg
# Captured and saved: captured_faces/face_91.jpg
# Captured and saved: captured_faces/face_92.jpg
# Captured and saved: captured_faces/face_93.jpg
# Captured and saved: captured_faces/face_94.jpg
# Captured and saved: captured_faces/face_95.jpg
# Captured and saved: captured_faces/face_96.jpg
# Captured and saved: captured_faces/face_97.jpg
# Captured and saved: captured_faces/face_98.jpg
# Captured and saved: captured_faces/face_99.jpg
# Captured and saved: captured_faces/face_100.jpg
# Captured and saved: captured_faces/face_101.jpg
# Captured and saved: captured_faces/face_102.jpg
# Captured and saved: captured_faces/face_103.jpg
# Captured and saved: captured_faces/face_104.jpg
# Captured and saved: captured_faces/face_105.jpg
# Captured and saved: captured_faces/face_106.jpg
# Captured and saved: captured_faces/face_107.jpg
# Captured and saved: captured_faces/face_108.jpg
# Captured and saved: captured_faces/face_109.jpg
# Captured and saved: captured_faces/face_110.jpg
# Captured and saved: captured_faces/face_111.jpg
# Captured and saved: captured_faces/face_112.jpg
# Captured and saved: captured_faces/face_113.jpg
# Captured and saved: captured_faces/face_114.jpg
# Captured and saved: captured_faces/face_115.jpg
# Captured and saved: captured_faces/face_116.jpg
# Captured and saved: captured_faces/face_117.jpg
# Captured and saved: captured_faces/face_118.jpg
# Captured and saved: captured_faces/face_119.jpg
# Captured and saved: captured_faces/face_120.jpg
# Captured and saved: captured_faces/face_121.jpg
# Captured and saved: captured_faces/face_122.jpg
# Captured and saved: captured_faces/face_123.jpg
# Captured and saved: captured_faces/face_124.jpg
# Captured and saved: captured_faces/face_125.jpg
# Captured and saved: captured_faces/face_126.jpg
# Captured and saved: captured_faces/face_127.jpg
# Captured and saved: captured_faces/face_128.jpg
# Captured and saved: captured_faces/face_129.jpg
# Captured and saved: captured_faces/face_130.jpg
# Captured and saved: captured_faces/face_131.jpg
# Captured and saved: captured_faces/face_132.jpg
# Captured and saved: captured_faces/face_133.jpg
# Captured and saved: captured_faces/face_134.jpg
# Captured and saved: captured_faces/face_135.jpg
# Captured and saved: captured_faces/face_136.jpg
# Captured and saved: captured_faces/face_137.jpg
# Captured and saved: captured_faces/face_138.jpg
# Captured and saved: captured_faces/face_139.jpg
# Captured and saved: captured_faces/face_140.jpg
# Captured and saved: captured_faces/face_141.jpg
# Captured and saved: captured_faces/face_142.jpg
# Captured and saved: captured_faces/face_143.jpg
# Captured and saved: captured_faces/face_144.jpg
# Captured and saved: captured_faces/face_145.jpg
# Captured and saved: captured_faces/face_146.jpg
# Captured and saved: captured_faces/face_147.jpg
# Captured and saved: captured_faces/face_148.jpg
# Captured and saved: captured_faces/face_149.jpg
# Captured and saved: captured_faces/face_150.jpg
# Captured and saved: captured_faces/face_151.jpg
# Captured and saved: captured_faces/face_152.jpg
# Captured and saved: captured_faces/face_153.jpg
# Captured and saved: captured_faces/face_154.jpg
# Captured and saved: captured_faces/face_155.jpg
# Captured and saved: captured_faces/face_156.jpg
# Captured and saved: captured_faces/face_157.jpg
# Captured and saved: captured_faces/face_158.jpg
# Captured and saved: captured_faces/face_159.jpg
# Captured and saved: captured_faces/face_160.jpg
# Captured and saved: captured_faces/face_161.jpg
# Captured and saved: captured_faces/face_162.jpg
# Captured and saved: captured_faces/face_163.jpg
# Captured and saved: captured_faces/face_164.jpg
# Captured and saved: captured_faces/face_165.jpg
# Captured and saved: captured_faces/face_166.jpg
# Captured and saved: captured_faces/face_167.jpg
# Captured and saved: captured_faces/face_168.jpg
# Captured and saved: captured_faces/face_169.jpg
# Captured and saved: captured_faces/face_170.jpg
# Captured and saved: captured_faces/face_171.jpg
# Captured and saved: captured_faces/face_172.jpg
# Captured and saved: captured_faces/face_173.jpg
# Captured and saved: captured_faces/face_174.jpg
# Captured and saved: captured_faces/face_175.jpg
# Captured and saved: captured_faces/face_176.jpg
# Captured and saved: captured_faces/face_177.jpg
# Captured and saved: captured_faces/face_178.jpg
# Captured and saved: captured_faces/face_179.jpg
# Captured and saved: captured_faces/face_180.jpg
# Captured and saved: captured_faces/face_181.jpg
# Captured and saved: captured_faces/face_182.jpg
# Captured and saved: captured_faces/face_183.jpg
# Captured and saved: captured_faces/face_184.jpg
# Captured and saved: captured_faces/face_185.jpg
# Captured and saved: captured_faces/face_186.jpg
# Captured and saved: captured_faces/face_187.jpg
# Captured and saved: captured_faces/face_188.jpg
# Captured and saved: captured_faces/face_189.jpg
# Captured and saved: captured_faces/face_190.jpg
# Captured and saved: captured_faces/face_191.jpg
# Captured and saved: captured_faces/face_192.jpg
# Captured and saved: captured_faces/face_193.jpg
# Captured and saved: captured_faces/face_194.jpg
# Captured and saved: captured_faces/face_195.jpg
# Captured and saved: captured_faces/face_196.jpg
# Captured and saved: captured_faces/face_197.jpg
# Captured and saved: captured_faces/face_198.jpg
# Captured and saved: captured_faces/face_199.jpg
# Captured and saved: captured_faces/face_200.jpg
# Captured 200 face images in color. Images are saved in 'captured_faces'.

# %%
# Paths to datasets
base_path = "./"  # Current directory
#person1_path = os.path.join(base_path, "Rahat")
person2_path = os.path.join(base_path, "Image")

# Variables
face_data = []
labels = []
label_dict = {0: "Muktadir"}  # Map labels to names
valid_extensions = (".jpg", ".jpeg", ".png")  # Valid file extensions

print("Paths and variables initialized.")
# Out:
# Paths and variables initialized.

# %%
def rename_images_in_directory(directory, prefix="image"):
    """Rename all images in a directory to a sequential format."""
    valid_extensions = (".jpg", ".jpeg", ".png")  # Allowed file extensions
    try:
        files = [f for f in os.listdir(directory) if f.lower().endswith(valid_extensions)]
        for i, filename in enumerate(files, start=163):
            old_path = os.path.join(directory, filename)
            new_filename = f"{prefix}{i}{os.path.splitext(filename)[1]}"  # Use same extension
            new_path = os.path.join(directory, new_filename)
            os.rename(old_path, new_path)
            print(f"Renamed: {old_path} -> {new_path}")
    except Exception as e:
        print(f"Error renaming files in {directory}: {e}")

# Rename images in both directories
#rename_images_in_directory(person1_path, prefix="Rahat")
rename_images_in_directory(person2_path, prefix="Muktadir")
# Out:
# Renamed: ./Image/face_53.jpg -> ./Image/Muktadir163.jpg
# Renamed: ./Image/face_47.jpg -> ./Image/Muktadir164.jpg
# Renamed: ./Image/face_90.jpg -> ./Image/Muktadir165.jpg
# Renamed: ./Image/face_149.jpg -> ./Image/Muktadir166.jpg
# Renamed: ./Image/face_175.jpg -> ./Image/Muktadir167.jpg
# Renamed: ./Image/face_161.jpg -> ./Image/Muktadir168.jpg
# Renamed: ./Image/face_85.jpg -> ./Image/Muktadir169.jpg
# Renamed: ./Image/face_78.jpg -> ./Image/Muktadir170.jpg
# Renamed: ./Image/face_50.jpg -> ./Image/Muktadir171.jpg
# Renamed: ./Image/face_87.jpg -> ./Image/Muktadir172.jpg
# Renamed: ./Image/face_177.jpg -> ./Image/Muktadir173.jpg
# Renamed: ./Image/face_163.jpg -> ./Image/Muktadir174.jpg
# Renamed: ./Image/face_189.jpg -> ./Image/Muktadir175.jpg
# Renamed: ./Image/face_176.jpg -> ./Image/Muktadir176.jpg
# Renamed: ./Image/face_92.jpg -> ./Image/Muktadir177.jpg
# Renamed: ./Image/face_45.jpg -> ./Image/Muktadir178.jpg
# Renamed: ./Image/face_200.jpg -> ./Image/Muktadir179.jpg
# Renamed: ./Image/face_55.jpg -> ./Image/Muktadir180.jpg
# Renamed: ./Image/face_96.jpg -> ./Image/Muktadir181.jpg
